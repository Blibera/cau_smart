# %%
import tensorflow as tf
tf.set_random_seed(777)

hello = tf.constant("Hello, TensorFlow!!")

sess = tf.Session()

print(sess.run(hello))
# Out:
# b'Hello, TensorFlow!!'

# %%
import tensorflow as tf


a = tf.constant([5],dtype=tf.float32)

b = tf.constant([10],dtype=tf.float32)

c = tf.constant([2],dtype=tf.float32)


d = a*b+c

d
# Out:
# <tf.Tensor 'add_1:0' shape=(1,) dtype=float32>

# %%
import tensorflow as tf


a = tf.constant([5],dtype=tf.float32)

b = tf.constant([10],dtype=tf.float32)

c = tf.constant([2],dtype=tf.float32)


d = a*b+c


sess = tf.Session()

result = sess.run(d)

result
# Out:
# array([52.], dtype=float32)

# %%
import tensorflow as tf

input_data = [1,2,3,4,5]

x = tf.placeholder(dtype=tf.float32)
W = tf.Variable([2],dtype=tf.float32)
y = W*x


sess = tf.Session()

#변수 초기화
init = tf.global_variables_initializer()
sess.run(init)

print(y)

result = sess.run(y,feed_dict={x:input_data})

result
# Out:
# Tensor("mul_11:0", dtype=float32)
# array([ 2.,  4.,  6.,  8., 10.], dtype=float32)

# %%
import tensorflow as tf
tf.set_random_seed(777)

# y = x + 2
x_train = [1, 2, 3, 4, 5, 6, 7]
y_train = [3, 4, 5, 6, 7, 8, 9]
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

cost = tf.reduce_mean(tf.square(hypothesis - y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 100 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 0.9128628 [0.8797735] [1.5562196]
# 100 0.0150435595 [1.0553737] [1.7257928]
# 200 0.006962396 [1.037671] [1.8134555]
# 300 0.0032223086 [1.0256277] [1.8730928]
# 400 0.0014913196 [1.0174347] [1.9136646]
# 500 0.0006902111 [1.0118608] [1.9412657]
# 600 0.00031943363 [1.008069] [1.9600431]
# 700 0.00014783186 [1.0054892] [1.9728175]
# 800 6.842027e-05 [1.0037345] [1.9815074]
# 900 3.1667587e-05 [1.0025406] [1.987419]
# 1000 1.4657339e-05 [1.0017284] [1.9914409]
# 1100 6.7837423e-06 [1.0011759] [1.9941775]
# 1200 3.1396553e-06 [1.0008] [1.9960386]
# 1300 1.4533224e-06 [1.0005443] [1.9973048]
# 1400 6.7281263e-07 [1.0003704] [1.9981663]
# 1500 3.114317e-07 [1.000252] [1.9987525]
# 1600 1.4411285e-07 [1.0001714] [1.9991512]
# 1700 6.6781965e-08 [1.0001166] [1.9994223]
# 1800 3.0962546e-08 [1.0000794] [1.9996067]
# 1900 1.4376034e-08 [1.0000541] [1.999732]
# 2000 6.6747896e-09 [1.000037] [1.9998174]

# %%
from __future__ import print_function

import tensorflow as tf
import numpy       # 파이썬 리스트로 제공되는 입력을 NumPy 배열로 바꾸기 위해 사용됩니다.
import matplotlib.pyplot as plt   # 그래프를 그리기 위해 사용됩니다.

tf.set_random_seed(777)

x_train = numpy.asarray([3.3,4.4,5.5,6.71,6.93,4.168,9.779,6.182,7.59,2.167,   # numpy.asarray 리스트를 배열로 변환합니다.
                         7.042,10.791,5.313,7.997,5.654,9.27,3.1])
y_train = numpy.asarray([1.7,2.76,2.09,3.19,1.694,1.573,3.366,2.596,2.53,1.221,
                         2.827,3.465,1.65,2.904,2.42,2.94,1.3])
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = x_train * W + b

cost = tf.reduce_mean(tf.square(hypothesis - y_train))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 100 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
        plt.plot(x_train, y_train, 'ro', label='Original data')            # 훈련 데이터를 점으로 표현합니다.ㅏ
        plt.plot(x_train, sess.run(W) * x_train + sess.run(b), label='Fitted line')  # 최종 결정된 모델 파라미터를 직선으로 표현합니다.
        plt.legend()  # plt.plot를 호출하면서 lable 아규먼트로 지정한 도표 설명을 화면에 보여줍니다.
        plt.show()
# Out:
# 0 1.4396842 [0.5606673] [-1.9992672]
# 100 0.7449091 [0.5598383] [-1.3862219]
# 200 0.51735854 [0.4933354] [-0.91474617]
# 300 0.37741318 [0.44118217] [-0.54500324]
# 400 0.2913459 [0.40028238] [-0.25504225]
# 500 0.23841387 [0.36820778] [-0.02764785]
# 600 0.20586033 [0.34305415] [0.15068023]
# 700 0.18583968 [0.32332805] [0.2905293]
# 800 0.17352682 [0.30785838] [0.40020233]
# 900 0.1659543 [0.2957267] [0.48621058]
# 1000 0.1612972 [0.2862127] [0.5536604]
# 1100 0.15843299 [0.27875164] [0.60655606]
# 1200 0.15667154 [0.2729005] [0.64803797]
# 1300 0.15558825 [0.2683119] [0.68056905]
# 1400 0.15492198 [0.26471338] [0.706081]
# 1500 0.15451223 [0.26189137] [0.72608787]
# 1600 0.15426025 [0.25967827] [0.74177754]
# 1700 0.15410528 [0.2579427] [0.75408196]
# 1800 0.15400995 [0.25658163] [0.76373136]
# 1900 0.15395133 [0.25551423] [0.7712989]
# 2000 0.15391529 [0.25467718] [0.7772331]
